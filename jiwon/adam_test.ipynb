# %%
# %run ../chap06/adam_model.ipynb
# %run ../chap06/dataset_office31.ipynb

# %%
od = Office31Dataset()

# %%
om1 = AdamModel('office31_model_1', od, [10])
om1.exec_all(epoch_count=20, report=10)
# Out:
# Model office31_model_1 train started:
#     Epoch 10: cost=4.296, accuracy=0.685+0.035/0.790+0.040 (38/38 secs)
#     Epoch 20: cost=4.268, accuracy=0.685+0.037/0.780+0.020 (38/76 secs)
# Model office31_model_1 train ended in 76 secs:
# Model office31_model_1 test report: accuracy = 0.661+0.048, (0 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 dslr => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 ring_binder => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 pen => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 mouse => X

# %%
om2 = AdamModel('office31_model_2', od, [64,32,10])
om2.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_2 train started:
#     Epoch 10: cost=3.739, accuracy=0.805+0.102/0.850+0.070 (115/115 secs)
#     Epoch 20: cost=3.448, accuracy=0.843+0.151/0.840+0.090 (124/239 secs)
#     Epoch 30: cost=3.238, accuracy=0.871+0.205/0.860+0.100 (114/353 secs)
#     Epoch 40: cost=3.079, accuracy=0.882+0.231/0.890+0.110 (114/467 secs)
#     Epoch 50: cost=2.936, accuracy=0.887+0.259/0.880+0.150 (109/576 secs)
# Model office31_model_2 train ended in 576 secs:
# Model office31_model_2 test report: accuracy = 0.872+0.206, (1 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [96, 1, 3] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 1, 0, 0,20, 5,11, 7,11,...] => 추정 bookcase : 정답 tape_dispenser => X
# 추정확률분포 [ 0, 0, 3, 0, 0, 0, 0, 0,...] => 추정 keyboard : 정답 letter_tray => X
# 추정확률분포 [ 0, 1, 0, 1, 1, 3, 1, 8,...] => 추정 pen : 정답 ruler => X

# %%
om3 = AdamModel('office31_model_3', od, [64,32,10])
om2.use_adam = True
om3.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_3 train started:
#     Epoch 10: cost=3.717, accuracy=0.818+0.082/0.860+0.050 (109/109 secs)
#     Epoch 20: cost=3.322, accuracy=0.866+0.159/0.880+0.130 (109/218 secs)
#     Epoch 30: cost=3.113, accuracy=0.880+0.201/0.880+0.180 (109/327 secs)
#     Epoch 40: cost=2.941, accuracy=0.893+0.234/0.870+0.250 (109/436 secs)
#     Epoch 50: cost=2.806, accuracy=0.905+0.267/0.880+0.200 (109/545 secs)
# Model office31_model_3 train ended in 545 secs:
# Model office31_model_3 test report: accuracy = 0.880+0.243, (0 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [99, 1, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 1, 1, 2, 4, 2, 2,10,...] => 추정 scissors : 정답 scissors => O
# 추정확률분포 [ 3, 1, 1,10, 5, 2, 0,10,...] => 추정 paper_notebook : 정답 printer => X
# 추정확률분포 [ 0, 0, 2, 2, 0, 1, 3, 1,...] => 추정 stapler : 정답 calculator => X
