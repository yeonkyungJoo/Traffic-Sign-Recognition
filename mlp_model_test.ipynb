# %%
# %run ../chap05/mlp_model.ipynb
# %run ../chap05/dataset_chap123.ipynb
# %run ../chap05/dataset_flowers.ipynb

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.191, accuracy=0.733/0.711 (1/1 secs)
#     Epoch 4: cost=7.392, accuracy=0.744/0.694 (0/1 secs)
#     Epoch 6: cost=7.247, accuracy=0.747/0.737 (0/1 secs)
#     Epoch 8: cost=7.139, accuracy=0.748/0.725 (0/1 secs)
#     Epoch 10: cost=7.054, accuracy=0.751/0.746 (0/1 secs)
# Model abalone_model train ended in 1 secs:
# Model abalone_model test report: accuracy = 0.727, (0 secs)
#
# Model abalone_model Visualization
# [0.00,0.00,1.00,0.70,0.53,0.17,1.56,0.61,0.39,0.44] => 추정 12.9 : 정답 10.0
# [0.00,1.00,0.00,0.46,0.38,0.12,0.48,0.22,0.10,0.17] => 추정  8.7 : 정답  7.0
# [0.00,0.00,1.00,0.58,0.45,0.14,1.14,0.56,0.22,0.29] => 추정 11.3 : 정답  8.0

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [4])
pm.exec_all()
# Out:
# Model pulsar_model train ended in 3 secs:
# Model pulsar_model test report: accuracy = 0.971, (0 secs)
#
# Model pulsar_model Visualization
# [121.8, 48.0,  0.2,...] => 추정 별(확률 0.01) : 정답 별 => O
# [143.5, 46.0, -0.3,...] => 추정 별(확률 0.00) : 정답 별 => O
# [170.4, 40.9, -0.9,...] => 추정 별(확률 0.01) : 정답 별 => O

# %%
pm.visualize(5)
# Out:
# Model pulsar_model Visualization
# [152.6, 47.2, -0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# [124.0, 49.3,  0.1,...] => 추정 별(확률 0.03) : 정답 별 => O
# [100.7, 41.3,  0.4,...] => 추정 별(확률 0.03) : 정답 별 => O
# [104.9, 37.0,  0.3,...] => 추정 별(확률 0.01) : 정답 별 => O
# [ 71.8, 34.0,  1.2,...] => 추정 별(확률 0.24) : 정답 별 => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.852, accuracy=0.345/0.361 (0/0 secs)
#     Epoch 20: cost=1.789, accuracy=0.345/0.361 (1/1 secs)
#     Epoch 30: cost=1.751, accuracy=0.345/0.361 (0/1 secs)
#     Epoch 40: cost=1.727, accuracy=0.345/0.361 (0/1 secs)
#     Epoch 50: cost=1.712, accuracy=0.345/0.361 (1/2 secs)
# Model steel_model train ended in 2 secs:
# Model steel_model test report: accuracy = 0.350, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 9,10,18, 8, 7,17,30] => 추정 Other_Faults : 정답 Other_Faults => O
# 추정확률분포 [ 9,10,18, 8, 7,17,30] => 추정 Other_Faults : 정답 Pastry => X
# 추정확률분포 [ 9,10,18, 8, 7,17,30] => 추정 Other_Faults : 정답 Bumps => X

# %%
# 모든 예제에 동일한 추정활률 분포가 구해지고 답은 언제나 other_faults가 나옴
#데이터 부족이 딥러닝에 어떤 결과를 보여주는지 극단적으로 보여주는 예
# Out:
#   File "<ipython-input-15-c71a083dcd3c>", line 2
#     데이터 부족이 딥러닝에 어떤 결과를 보여주는지 극단적으로 보여주는 예
#           ^
# SyntaxError: invalid syntax

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [4])
psm.exec_all()
# Out:
# Model pulsar_select_model train ended in 4 secs:
# Model pulsar_select_model test report: accuracy = 0.971, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [92, 8] => 추정 별 : 정답 별 => O
# 추정확률분포 [95, 5] => 추정 별 : 정답 별 => O
# 추정확률분포 [94, 6] => 추정 별 : 정답 별 => O

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.772, accuracy=0.244/0.280 (8/8 secs)
#     Epoch 4: cost=1.752, accuracy=0.244/0.300 (8/16 secs)
#     Epoch 6: cost=1.735, accuracy=0.244/0.250 (8/24 secs)
#     Epoch 8: cost=1.724, accuracy=0.244/0.270 (7/31 secs)
#     Epoch 10: cost=1.711, accuracy=0.244/0.310 (8/39 secs)
# Model flowers_model_1 train ended in 39 secs:
# Model flowers_model_1 test report: accuracy = 0.239, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 sunflower => X
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 rose => X

# %%
fm2 = MlpModel('flowers_model_2', fd, [30, 10])
fm2.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.587, accuracy=0.282/0.280 (14/14 secs)
#     Epoch 4: cost=1.393, accuracy=0.384/0.350 (14/28 secs)
#     Epoch 6: cost=1.328, accuracy=0.424/0.300 (13/41 secs)
#     Epoch 8: cost=1.274, accuracy=0.446/0.390 (14/55 secs)
#     Epoch 10: cost=1.242, accuracy=0.465/0.410 (13/68 secs)
# Model flowers_model_2 train ended in 68 secs:
# Model flowers_model_2 test report: accuracy = 0.411, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [27, 8, 4,30, 6,26] => 추정 rose : 정답 sunflower => X
# 추정확률분포 [25,74, 0, 0, 0, 1] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [10,23, 0, 6,47,15] => 추정 sunflower : 정답 dandelion => X
